# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())
c = int(input())

p = (a + b + c) / 2
S = (p*(p-a)*(p-b)*(p-c))**0.5
         
print(S)
# Out:
# 6.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = int(input())

if (x > (-15) and x <= 12) or (x > 14 and x < 17) or x >= 19:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)
