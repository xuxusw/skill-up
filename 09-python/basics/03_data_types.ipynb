# %% [markdown]
# Стандартные типы данных:
#
# числовые:
# * целые числа - int
# * вещественные (с плавающей точкой) - float
# * логические - bool
#
# строковые:
# * строки - string
#
# Все перечисленные типы являются НЕИЗМЕНЯЕМЫМИ.
# Чтобы изменить объект с таким типом, нужно создавать новый объект с новым значением.

# %%
# преобразование типов (чтобы изменить один тип на другой)

a = 12.3
print(a)
print(type(a))

a2 = int(a)
print(a2)
print(type(a2))

a3 = float(a2)
print(a3)
print(type(a3))
# Out:
# 12.3
# <class 'float'>
# 12
# <class 'int'>
# 12.0
# <class 'float'>

# %%
9**19 - int(float(9**19))
# Out:
# 89

# %% [markdown]
# Представление вещественных чисел в компьютере: https://habr.com/ru/articles/112953/

# %%
0.3 + 0.3 + 0.3
# Out:
# 0.8999999999999999

# %% [markdown]
# Тип объекта
# - определяет множество значений, которые может принимать объект заданного типа;
# - определяет операции, которые могут быть применены к объекту.

# %% [markdown]
# Все объекты в Python характеризуются своим типом данных.
