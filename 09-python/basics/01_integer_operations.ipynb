# %% [markdown]
# Бинарные операторы (у каждого есть левый операнд и правый операнд)

# %%
11111 * 1111111
# Out:
# 12345554321

# %%
42 / (4 + 2 * (-2))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 42 / (4 + 2 * (-2))
#
# ZeroDivisionError: division by zero

# %%
239 % 10
# Out:
# 9

# %%
239 // 10
# Out:
# 23

# %%
239 / 10
# Out:
# 23.9

# %%
2**5
# Out:
# 32

# %%
2^5
# Out:
# 7

# %%
2**3
# Out:
# 8

# %%
2014**14
# Out:
# 18064773765607550801425251468864907833685590016

# %% [markdown]
# доп

# %%
import math

math.sqrt(25)
# Out:
# 5.0

# %%
import numpy as np

np.sqrt([2, 3])
# Out:
# array([1.41421356, 1.73205081])

# %% [markdown]
# Унарные операторы (принимают 1 аргумент)

# %%
- (42)
# Out:
# -42

# %%
+ (42)
# Out:
# 42

# %%
+-+42
# Out:
# -42
