# %%
'string'
'string2'

'''miltiple lines 
string'''

"""multiple lines 
string2"""

# %%
# конкатенация
concat = 'abc' + 'def'
print(concat)
# Out:
# abcdef

# %%
'abc' * 3
# Out:
# 'abcabcabc'

# %%
print(len(concat))
print(len('abc'))
# Out:
# 6
# 3

# %% [markdown]
# Строки сравниваются в лексикографическом порядке

# %%
'abc' == 'abc'
# Out:
# True

# %%
'abc' < 'ac'
# Out:
# True

# %%
'abc' > 'ab'
# Out:
# True

# %%
# символ перевода строки

print('first line', '\n\n\nlast line')
# Out:
# first line
#
#
# last line

# %%
print("239" < "30" and 239 < 30)
print("239" < "30" and 239 > 30)
print("239" > "30" and 239 < 30)
print("239" > "30" and 239 > 30)
# Out:
# False
# True
# False
# False
