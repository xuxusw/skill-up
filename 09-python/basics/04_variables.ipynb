# %% [markdown]
# Переменные - имена объектов.
# Позволяют обращаться к объектам по имени.
# = - оператор присваивания (имени переменной)

# %% [markdown]
# текущее значение переменной

# %% [markdown]
# Операторы приращения:
# +=
# -=
# *=
# /=
# //=
# %=
# **=

# %% [markdown]
# Динамическая типизация - одна и та же переменная может связываться с объектами разных типов.

# %%
name = 'july'
items = ['june', 'july', 'august'] 

def foo(name, data_list):
    return ['august' if x == name else x for x in data_list]

a = 2
print(type(a))

a = 'ababa'
print(type(a))

a = foo(name, items)
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %% [markdown]
# То есть в Python не совсем корректно говорить о том, что переменная имеет какой-то тип конкретный. Можно говорить только о том, что переменная имеет конкретный тип в конкретный момент выполнения программы, когда переменная связана с каким-то конкретным объектом.  (динамическая типизация)
#
# Этим Python отличается от языков со статической типизацией.

# %%
in1 = input('введите первое число: ')
print(in1)
print(type(in1))

in2 = int(input('введите второе число: '))
print(in2)
print(type(in2))
# Out:
# 34
# <class 'str'>
# 55
# <class 'int'>

# %%
a = 3
print(a)

a += 4
print(a)

print(2*a)
# Out:
# 3
# 7
# 14

# %%
name = input()
print('Hello,', name)
# Out:
# Hello, Jess

# %%
# Тимофей обычно спит ночью X часов и устраивает себе днем тихий час на Y минут. 
# Определите, сколько всего минут Тимофей спит в сутки.

X = int(input())
Y = int(input())
print(X*60 + Y)
# Out:
# 450

# %%
# Коля каждый день ложится спать ровно в полночь и недавно узнал, что оптимальное время для его сна составляет X минут. 
# Коля хочет поставить себе будильник так, чтобы он прозвенел ровно через X минут после полуночи, 
# однако для этого необходимо указать время сигнала в формате часы, минуты. 
# Помогите Коле определить, на какое время завести будильник.

X = int(input())
print(X//60)
print(X%60)
# Out:
# 8
# 32

# %%
# Катя узнала, что ей для сна надо X минут. В отличие от Коли, Катя ложится спать после полуночи в H часов и M минут. 
# Помогите Кате определить, на какое время ей поставить будильник, чтобы он прозвенел ровно через X минут после того, как она ляжет спать.
# На стандартный ввод, каждое в своей строке, подаются значения X, H и M. 
# Гарантируется, что Катя должна проснуться в тот же день, что и заснуть.
# Программа должна выводить время, на которое нужно поставить будильник: в первой строке часы, во второй — минуты.

X = int(input())
H = int(input())
M = int(input())
hours = X//60 + H
minutes = X%60 + M
if minutes > 60:
    print(hours+1)
    print(minutes%60)
else:
    print(hours)
    print(minutes)
# Out:
# 9
# 50
